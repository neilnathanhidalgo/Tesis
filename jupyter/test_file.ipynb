# %%
import pandas as pd
import numpy as np
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# %%
data = pd.read_csv(f"../data/preprocessed_data/Mhealth_150_25.csv")
max_depth=pd.read_csv("../data/outputs/md_per_config.csv")

data.drop(["Sensor", "ID", "DTS", "Subject"], axis=1, inplace=True)

y = data['Activity']
data.drop("Activity", axis=1, inplace=True)

X = data[data.columns.to_list()]

# Dividir en conjunto de entrenamiento y prueba
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=0)

print(x_test.filter(like='tChest'))
# Out:
#       max_Acctr_tChest_X(m/s2)  max_Acctr_tChest_Y(m/s2)  \
# 2344                   -9.1456                  -1.31170
# 370                    -0.1705                   0.60729
# 1307                   -2.9255                   5.67550
# 819                    -4.6060                   2.43810
# 2790                   -8.7472                   0.20858
# ...                        ...                       ...
# 788                    -4.8982                   3.88510
# 1568                   -5.4779                   4.48320
# 1306                   -4.6102                   2.72820
# 762                    -8.2829                   0.38143
# 1284                   -5.1916                   4.17750
#
#       max_Acctr_tChest_Z(m/s2)  mean_Acctr_tChest_X(m/s2)  \
# 2344                   0.66650                  -9.616982
# 370                   10.50700                  -0.751181
# 1307                   2.16230                  -9.650880
# 819                   -4.18840                  -7.528666
# 2790                   1.61890                  -9.584929
# ...                        ...                        ...
# 788                    0.39894                  -7.471297
# 1568                   0.86695                  -9.770342
# 1306                   0.76776                  -9.568697
# 762                    2.77130                  -9.578932
# 1284                   1.36280                  -9.776469
#
#       mean_Acctr_tChest_Y(m/s2)  mean_Acctr_tChest_Z(m/s2)  \
# 2344                  -1.857702                   0.092386
# 370                    0.134761                   9.934375
# 1307                   0.365858                  -1.064753
# 819                    0.595087                  -5.865881
# 2790                  -0.928893                  -0.742615
# ...                         ...                        ...
# 788                    0.302794                  -4.673167
# 1568                  -0.536749                  -1.118974
# 1306                  -0.642977                  -1.372041
# 762                   -0.427205                   1.330109
# 1284                  -0.719576                  -1.327148
#
#       median_Acctr_tChest_X(m/s2)  median_Acctr_tChest_Y(m/s2)  \
# 2344                     -9.61240                    -1.866850
# 370                      -0.77434                     0.134750
# 1307                     -9.28530                     0.191970
# 819                      -7.58065                     0.566360
# 2790                     -9.55070                    -0.948735
# ...                           ...                          ...
# 788                      -6.97930                     0.017851
# 1568                     -9.89220                    -0.628460
# 1306                     -9.22770                    -0.675725
# 762                      -9.53315                    -0.429000
# 1284                     -9.71770                    -0.788495
#
#       median_Acctr_tChest_Z(m/s2)  min_Acctr_tChest_X(m/s2)  ...  \
# 2344                     0.085923                  -10.0480  ...
# 370                      9.954450                   -1.2216  ...
# 1307                    -0.747040                  -18.9350  ...
# 819                     -5.858550                  -11.6900  ...
# 2790                    -0.435805                  -10.5990  ...
# ...                           ...                       ...  ...
# 788                     -3.160900                  -10.6190  ...
# 1568                    -0.972585                  -14.4120  ...
# 1306                    -1.231150                  -16.0670  ...
# 762                      1.970950                  -10.5550  ...
# 1284                    -0.944120                  -15.0260  ...
#
#       min_Acctr_tChest_Z(m/s2)  rango_Acctr_tChest_X(m/s2)  \
# 2344                  -0.43814                      0.9024
# 370                    9.44790                      1.0511
# 1307                  -5.13660                     16.0095
# 819                   -7.65380                      7.0840
# 2790                  -3.25720                      1.8518
# ...                        ...                         ...
# 788                  -12.24400                      5.7208
# 1568                  -4.12800                      8.9341
# 1306                  -4.48170                     11.4568
# 762                   -0.95891                      2.2721
# 1284                  -6.18350                      9.8344
#
#       rango_Acctr_tChest_Y(m/s2)  rango_Acctr_tChest_Z(m/s2)  \
# 2344                     0.80870                     1.10464
# 370                      0.82234                     1.05910
# 1307                     8.63830                     7.29890
# 819                      3.36149                     3.46540
# 2790                     2.64018                     4.87610
# ...                          ...                         ...
# 788                      5.38830                    12.64294
# 1568                     7.25930                     4.99495
# 1306                     5.69100                     5.24946
# 762                      1.59163                     3.73021
# 1284                     9.85660                     7.54630
#
#       std_Acctr_tChest_X(m/s2)  std_Acctr_tChest_Y(m/s2)  \
# 2344                  0.150649                  0.137918
# 370                   0.152031                  0.146227
# 1307                  2.972763                  1.850831
# 819                   1.236459                  0.669969
# 2790                  0.381948                  0.397855
# ...                        ...                       ...
# 788                   1.576549                  0.905245
# 1568                  2.243625                  1.288569
# 1306                  2.615808                  1.217807
# 762                   0.363295                  0.292039
# 1284                  2.553899                  1.643661
#
#       std_Acctr_tChest_Z(m/s2)  var_Acctr_tChest_X(m/s2)  \
# 2344                  0.177547                  0.022695
# 370                   0.170465                  0.023113
# 1307                  1.562850                  8.837319
# 819                   0.641774                  1.528832
# 2790                  1.218232                  0.145885
# ...                        ...                       ...
# 788                   4.132391                  2.485507
# 1568                  1.168942                  5.033851
# 1306                  1.221196                  6.842454
# 762                   1.197434                  0.131983
# 1284                  1.508772                  6.522401
#
#       var_Acctr_tChest_Y(m/s2)  var_Acctr_tChest_Z(m/s2)
# 2344                  0.019021                  0.031523
# 370                   0.021382                  0.029058
# 1307                  3.425577                  2.442500
# 819                   0.448858                  0.411874
# 2790                  0.158288                  1.484090
# ...                        ...                       ...
# 788                   0.819468                 17.076652
# 1568                  1.660409                  1.366424
# 1306                  1.483053                  1.491319
# 762                   0.085287                  1.433849
# 1284                  2.701620                  2.276394
#
# [874 rows x 21 columns]

# %%
data = pd.read_csv(f"../data/preprocessed_data/Mhealth_150_25.csv")

data.drop(["Sensor", "ID", "DTS", "Subject"], axis=1, inplace=True)

Y_tChest = data["Activity"]
Y_tLA = data["Activity"]
Y_tRLA = data["Activity"]

data.drop("Activity", axis=1, inplace=True)

X = data[data.columns.to_list()]

X_tChest = X.filter(like='tChest')
X_tLA = X.filter(like='tLA')
X_tRLA = X.filter(like='tRLA')

x_tChest, X_test_tChest, y_tChest , y_test_tChest = train_test_split(X_tChest,Y_tChest,test_size=0.3, stratify=Y_tChest, random_state=0)
x_tLA, X_test_tLA, y_tLA , y_test_tLA = train_test_split(X_tLA,Y_tLA,test_size=0.3, stratify=Y_tLA, random_state=0)
x_tRLA, X_test_tRLA, y_tRLA , y_test_tRLA = train_test_split(X_tRLA,Y_tRLA,test_size=0.3, stratify=Y_tRLA, random_state=0)

print(X_test_tChest)
# Out:
#       max_Acctr_tChest_X(m/s2)  max_Acctr_tChest_Y(m/s2)  \
# 2344                   -9.1456                  -1.31170
# 370                    -0.1705                   0.60729
# 1307                   -2.9255                   5.67550
# 819                    -4.6060                   2.43810
# 2790                   -8.7472                   0.20858
# ...                        ...                       ...
# 788                    -4.8982                   3.88510
# 1568                   -5.4779                   4.48320
# 1306                   -4.6102                   2.72820
# 762                    -8.2829                   0.38143
# 1284                   -5.1916                   4.17750
#
#       max_Acctr_tChest_Z(m/s2)  mean_Acctr_tChest_X(m/s2)  \
# 2344                   0.66650                  -9.616982
# 370                   10.50700                  -0.751181
# 1307                   2.16230                  -9.650880
# 819                   -4.18840                  -7.528666
# 2790                   1.61890                  -9.584929
# ...                        ...                        ...
# 788                    0.39894                  -7.471297
# 1568                   0.86695                  -9.770342
# 1306                   0.76776                  -9.568697
# 762                    2.77130                  -9.578932
# 1284                   1.36280                  -9.776469
#
#       mean_Acctr_tChest_Y(m/s2)  mean_Acctr_tChest_Z(m/s2)  \
# 2344                  -1.857702                   0.092386
# 370                    0.134761                   9.934375
# 1307                   0.365858                  -1.064753
# 819                    0.595087                  -5.865881
# 2790                  -0.928893                  -0.742615
# ...                         ...                        ...
# 788                    0.302794                  -4.673167
# 1568                  -0.536749                  -1.118974
# 1306                  -0.642977                  -1.372041
# 762                   -0.427205                   1.330109
# 1284                  -0.719576                  -1.327148
#
#       median_Acctr_tChest_X(m/s2)  median_Acctr_tChest_Y(m/s2)  \
# 2344                     -9.61240                    -1.866850
# 370                      -0.77434                     0.134750
# 1307                     -9.28530                     0.191970
# 819                      -7.58065                     0.566360
# 2790                     -9.55070                    -0.948735
# ...                           ...                          ...
# 788                      -6.97930                     0.017851
# 1568                     -9.89220                    -0.628460
# 1306                     -9.22770                    -0.675725
# 762                      -9.53315                    -0.429000
# 1284                     -9.71770                    -0.788495
#
#       median_Acctr_tChest_Z(m/s2)  min_Acctr_tChest_X(m/s2)  ...  \
# 2344                     0.085923                  -10.0480  ...
# 370                      9.954450                   -1.2216  ...
# 1307                    -0.747040                  -18.9350  ...
# 819                     -5.858550                  -11.6900  ...
# 2790                    -0.435805                  -10.5990  ...
# ...                           ...                       ...  ...
# 788                     -3.160900                  -10.6190  ...
# 1568                    -0.972585                  -14.4120  ...
# 1306                    -1.231150                  -16.0670  ...
# 762                      1.970950                  -10.5550  ...
# 1284                    -0.944120                  -15.0260  ...
#
#       min_Acctr_tChest_Z(m/s2)  rango_Acctr_tChest_X(m/s2)  \
# 2344                  -0.43814                      0.9024
# 370                    9.44790                      1.0511
# 1307                  -5.13660                     16.0095
# 819                   -7.65380                      7.0840
# 2790                  -3.25720                      1.8518
# ...                        ...                         ...
# 788                  -12.24400                      5.7208
# 1568                  -4.12800                      8.9341
# 1306                  -4.48170                     11.4568
# 762                   -0.95891                      2.2721
# 1284                  -6.18350                      9.8344
#
#       rango_Acctr_tChest_Y(m/s2)  rango_Acctr_tChest_Z(m/s2)  \
# 2344                     0.80870                     1.10464
# 370                      0.82234                     1.05910
# 1307                     8.63830                     7.29890
# 819                      3.36149                     3.46540
# 2790                     2.64018                     4.87610
# ...                          ...                         ...
# 788                      5.38830                    12.64294
# 1568                     7.25930                     4.99495
# 1306                     5.69100                     5.24946
# 762                      1.59163                     3.73021
# 1284                     9.85660                     7.54630
#
#       std_Acctr_tChest_X(m/s2)  std_Acctr_tChest_Y(m/s2)  \
# 2344                  0.150649                  0.137918
# 370                   0.152031                  0.146227
# 1307                  2.972763                  1.850831
# 819                   1.236459                  0.669969
# 2790                  0.381948                  0.397855
# ...                        ...                       ...
# 788                   1.576549                  0.905245
# 1568                  2.243625                  1.288569
# 1306                  2.615808                  1.217807
# 762                   0.363295                  0.292039
# 1284                  2.553899                  1.643661
#
#       std_Acctr_tChest_Z(m/s2)  var_Acctr_tChest_X(m/s2)  \
# 2344                  0.177547                  0.022695
# 370                   0.170465                  0.023113
# 1307                  1.562850                  8.837319
# 819                   0.641774                  1.528832
# 2790                  1.218232                  0.145885
# ...                        ...                       ...
# 788                   4.132391                  2.485507
# 1568                  1.168942                  5.033851
# 1306                  1.221196                  6.842454
# 762                   1.197434                  0.131983
# 1284                  1.508772                  6.522401
#
#       var_Acctr_tChest_Y(m/s2)  var_Acctr_tChest_Z(m/s2)
# 2344                  0.019021                  0.031523
# 370                   0.021382                  0.029058
# 1307                  3.425577                  2.442500
# 819                   0.448858                  0.411874
# 2790                  0.158288                  1.484090
# ...                        ...                       ...
# 788                   0.819468                 17.076652
# 1568                  1.660409                  1.366424
# 1306                  1.483053                  1.491319
# 762                   0.085287                  1.433849
# 1284                  2.701620                  2.276394
#
# [874 rows x 21 columns]
